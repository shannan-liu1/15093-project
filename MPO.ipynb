# %%
using DataFrames, CSV
using JLD
using JuMP, Gurobi
using LinearAlgebra, Random, Printf, StatsBase, CategoricalArrays
using Plots, StatsPlots
using Distributions

# %%
v = CSV.read("/Users/shann/Documents/GitHub/15093-project/universe/volatility_500.csv", DataFrame)
r = CSV.read("/Users/shann/Documents/GitHub/15093-project/universe/returns_500.csv", DataFrame)
s = CSV.read("/Users/shann/Documents/GitHub/15093-project/universe/sectors_500.csv", DataFrame)
p = CSV.read("/Users/shann/Documents/GitHub/15093-project/universe/price_500.csv", DataFrame)
cor = CSV.read("/Users/shann/Documents/GitHub/15093-project/universe/correlations_500.csv", DataFrame)
cov = CSV.read("/Users/shann/Documents/GitHub/15093-project/universe/covariance_500.csv", DataFrame)
tbill = 0.029339583
# Out:
# 0.029339583

# %%
# correlation matrix of r v r
cor[2:end, 2:end]
# Out:
# 479×480 DataFrame
#  Row │ MMM_returns_volatility  AOS_returns_volatility  ABT_returns_volatility  ⋯
#      │ Float64                 Float64                 Float64                 ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │              0.470788                 1.0                     0.193155  ⋯
#    2 │              0.226991                 0.193155                1.0
#    3 │              0.151466                 0.13399                 0.226099
#    4 │              0.108066                 0.222017                0.147231
#    5 │              0.385744                 0.367218                0.270492  ⋯
#    6 │              0.14894                  0.1406                  0.201587
#    7 │              0.287415                 0.214695                0.116049
#    8 │              0.301581                 0.235392                0.322589
#   ⋮  │           ⋮                       ⋮                       ⋮             ⋱
# ...
